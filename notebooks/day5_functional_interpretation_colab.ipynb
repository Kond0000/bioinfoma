# %% [markdown]
# # Day5: Functional Interpretation
#
# このノートブックは GO や経路解析の入口です。
#
# 目的:
# - 遺伝子リストを生物学的意味に結びつける
# - 上昇遺伝子と低下遺伝子を解釈する
# - 結果を文章で説明する練習をする

# %% [markdown]
# ## このトピックでやること
#
# 1. 差次的発現遺伝子を準備する
# 2. enrichment の考え方を学ぶ
# 3. 生物学的な意味を短く言語化する

# %% [markdown]
# ## ステータス
#
# このノートブックは入口を先に用意した段階です。次に実装を入れていきます。
