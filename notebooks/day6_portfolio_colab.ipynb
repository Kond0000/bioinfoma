# %% [markdown]
# # Day6: Portfolio
#
# このノートブックは GitHub 公開用ポートフォリオ整理の入口です。
#
# 目的:
# - 解析の流れを他人に伝わる形にする
# - 図と説明を対応づける
# - README の書き方を揃える

# %% [markdown]
# ## このトピックでやること
#
# 1. 何を解析したかを短く書く
# 2. 主要な図を並べる
# 3. 学習ログではなく成果物として見せる

# %% [markdown]
# ## ステータス
#
# このノートブックは入口を先に用意した段階です。次に実装を入れていきます。
